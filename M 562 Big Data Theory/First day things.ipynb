# %% [markdown]
# # Machine Learning / Data Science Algorithms

# %% [markdown]
# Things we are gonna do:
#
# **REGRESSION:** predict a continuous variable
#
# Train a linear regression model
#
# Make linear regression nonlinear (by adding polynomial features)
#
# Overfitting and regularization
#
# Kernel trick (black magic)
#
# **Classification:** predict a discrete variable
#
# Logistic Regression
#
# Softmax regression
#
# knn (k nearest neighbors)
#
# **Clustering:** Find groups of similar objects
#
# k-means
#
# hierarchical clustering
#
# Gaussian mixtures
#
# **Recommender System:** predict user preference
#
# We'll build a movie recommender
#
# **Deep Learning:** for regression/classification
#
# We'll build a neural network- from scratch !!
#
# ****
#
# Grades based on:
#
# Homework: 80%
#
# Final Project: 20%  (He will send a list with ideas)
#
# ****
#
# Tools we'll need:
#
# Python
#
# Python Libraries: numpy, matplotlib, pandas
#
# Jupyter notebooks

# %% [markdown]
# ### Useful Jupyter shortcuts
#
# enter + shift: runs a cell
#
# a: creates a cell above currently selected cell
#
# b: creates a cell below currently selected cell
#
# d+d: deletes currently selected cell
#
# h: list of all keyboard shortcuts

# %% [markdown]
# Nested Itemized Lists:
#
# - item 1
#     - item 1.1
#     - item 1.2
#         - item 1.2.1
# - item 2

# %% [markdown]
# Look up 'markdownguide.org' to see what you can do.

# %%
import numpy as np

# %%
2+2
# Out:
# 4

# %%
a = 1
b = 0.5

a+b
# Out:
# 1.5

# %%
print('hello world')
# Out:
# hello world

# %%
def my_boring_function(x):
    return x*x

# %%
my_boring_function(3)
# Out:
# 9

# %%
my_boring_function(np.array([2,2]))
# Out:
# array([4, 4])

# %%
# create a vector from a list

v = np.array([1,2,3])
v
# Out:
# array([1, 2, 3])

# %%
v.shape
# Out:
# (3,)

# %%
v.flatten?

# %%
i = np.zeros(2)

# %%
i
# Out:
# array([1., 1.])

# %%
i[0].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-87692576bb10> in <module>
# ----> 1 i[0].type
#
# AttributeError: 'numpy.float64' object has no attribute 'type'
