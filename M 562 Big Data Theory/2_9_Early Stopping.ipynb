# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Early Stopping of Gradient Descent
#
# With gradient descent, we can regularize a linear regression model without adding a regularization term by stopping early (kind of)
